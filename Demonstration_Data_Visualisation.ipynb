# %%
import pandas as pd

df = pd.read_csv('demoStatsGrid.csv')
df.drop(index=df.index[0], axis=0, inplace=True)
display(df)
# Out:
#       Episode Number   Total Reward   Total Steps
# 1                  2            0.5             5 NaN
# 2                  3            0.8             2 NaN
# 3                  4            0.5             5 NaN
# 4                  5            0.7             3 NaN
# 5                  6            0.7             3 NaN
# ...              ...            ...           ...  ..
# 2329            2330            0.6             4 NaN
# 2330            2331            0.4             6 NaN
# 2331            2332            0.7             3 NaN
# 2332            2333            0.7             3 NaN
# 2333            2334            0.8             2 NaN
#
# [2333 rows x 4 columns]

# %%
df.describe()
# Out:
#        Episode Number   Total Reward   Total Steps
# count     2333.000000    2333.000000   2333.000000  0.0
# mean      1168.000000       0.664338      3.356622  NaN
# std        673.623411       0.106948      1.069476  NaN
# min          2.000000       0.400000      2.000000  NaN
# 25%        585.000000       0.600000      3.000000  NaN
# 50%       1168.000000       0.700000      3.000000  NaN
# 75%       1751.000000       0.700000      4.000000  NaN
# max       2334.000000       0.800000      6.000000  NaN

# %%
df[' Total Steps'].sum()
# Out:
# 7831

# %%
# @title  Total Reward

from matplotlib import pyplot as plt
df[' Total Reward'].plot(kind='line', figsize=(8, 4), title=' Grid World Demo Total Reward')
plt.ylim((0,1))
plt.xlim((0))
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.axhline(y=0.664338, color='r', linestyle='dotted')
plt.legend(["reward", "mean reward"], loc="lower right")

plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df = pd.read_csv('demoStatsExit.csv')
df.drop(index=df.index[0], axis=0, inplace=True)


df = df.drop(df[df[" Total Reward"] < 0.62].index)

from matplotlib import pyplot as plt
df[' Total Reward'].plot(kind='line', figsize=(8, 4), title=' Find Exit Agent Demo Total Reward')
plt.ylim((0,2))
plt.xlim((0))
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.axhline(y=1.444716, color='r', linestyle='dotted')
plt.legend(["reward", "mean reward"], loc="lower right")

plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.describe()
# Out:
#        Episode Number   Total Reward   Total Steps
# count          68.000      68.000000     68.000000  0.0
# mean           35.750       1.444716    166.382353  NaN
# std            20.103       0.152902     53.521938  NaN
# min             2.000       1.092421     82.000000  NaN
# 25%            18.750       1.353784    130.000000  NaN
# 50%            35.500       1.417971    157.000000  NaN
# 75%            52.500       1.504424    195.250000  NaN
# max            70.000       1.900034    373.000000  NaN

# %%
df[' Total Steps'].sum()
# Out:
# 11314

# %%
df = pd.read_csv('demoStatsComplex.csv')
df.drop(index=df.index[0], axis=0, inplace=True)

from matplotlib import pyplot as plt
df[' Total Reward'].plot(kind='line', figsize=(8, 4), title=' 3D Space Shooter Demo Total Reward')
plt.ylim((0,2))
plt.xlim((0))
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.axhline(y=1.385507, color='r', linestyle='dotted')
plt.legend(["reward", "mean reward"], loc="lower right")

plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.describe()
# Out:
#        Episode Number   Total Reward   Total Steps
# count       51.000000      51.000000     51.000000  0.0
# mean        27.000000       1.385507    528.274510  NaN
# std         14.866069       0.064422    117.766222  NaN
# min          2.000000       1.140739    312.000000  NaN
# 25%         14.500000       1.349747    443.000000  NaN
# 50%         27.000000       1.400430    505.000000  NaN
# 75%         39.500000       1.434569    603.000000  NaN
# max         52.000000       1.489159    954.000000  NaN

# %%
df[' Total Steps'].sum()
# Out:
# 26942

# %%
df = pd.read_csv('demoStatsComplex.csv')
df.drop(index=df.index[0], axis=0, inplace=True)

from matplotlib import pyplot as plt
#df[' Total Reward'].plot(kind='line', figsize=(8, 4), title=' 3D Space Shooter Demo Total Reward')
plt.ylim((0,2700))
plt.xlim((0,11))
plt.title("Crawler Demo Total Reward")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.axhline(y=2527.892, color='r', linestyle='dotted')
plt.legend(["mean reward"], loc="lower right")

plt.gca().spines[['top', 'right']].set_visible(False)
